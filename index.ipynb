# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from numpy import random
from scipy.ndimage.filters import gaussian_filter

# %%
x = random.randn(10,500)
x = gaussian_filter(x, [0, 10])
sns.tsplot(x, err_style='unit_traces');
# Out:
# C:\Users\Tarun\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
mat = random.randn(10,20)
sns.heatmap(mat);
